# %%
import pylheV
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set() #Set style
sns.set_style('ticks',{'font.family':'serif', 'font.serif':'Times New Roman'})
sns.set_context('paper', font_scale=1.8)
sns.set_palette(sns.color_palette("Paired"))

# %%
for e in pylheV.readLHE('../pp2ttbar.lhe'): 
    for i in range(int(e.eventinfo.nparticles)):
        
        print(e.particles[i].daughters)
# Out:
# <bound method LHEParticle.daughters of <pylheV.LHEParticle object at 0x7f31f912cdf0>>
# <bound method LHEParticle.daughters of <pylheV.LHEParticle object at 0x7f31f912cdc0>>
# <bound method LHEParticle.daughters of <pylheV.LHEParticle object at 0x7f31f912ce20>>
# <bound method LHEParticle.daughters of <pylheV.LHEParticle object at 0x7f31f912ce50>>
# <bound method LHEParticle.daughters of <pylheV.LHEParticle object at 0x7f31f914d2e0>>
# <bound method LHEParticle.daughters of <pylheV.LHEParticle object at 0x7f31f914d310>>
# <bound method LHEParticle.daughters of <pylheV.LHEParticle object at 0x7f31f914d340>>
# <bound method LHEParticle.daughters of <pylheV.LHEParticle object at 0x7f31f914d370>>
# <bound method LHEParticle.daughters of <pylheV.LHEParticle object at 0x7f31f914d6d0>>
# <bound method LHEParticle.daughters of <pylheV.LHEParticle object at 0x7f31f914d700>>
# <bound method LHEParticle.daughters of <pylheV.LHEParticle object at 0x7f31f914d730>>
# ...

# %%
#Teste para estrutura do código que ira ser feito no pylheV.py

for e in pylheV.readLHE('pp2ttbar.lhe'):
    for i in range(int(e.eventinfo.nparticles)):
        e.particles[i].daughters = []
    for i in range(int(e.eventinfo.nparticles)):
        if e.particles[i].mother1 != 0:
            mother1_idx = int(e.particles[i].mother1)-1
            e.particles[mother1_idx].daughters = e.particles[mother1_idx].daughters + [i]
            
        if e.particles[i].mother2 != 0:
            mother2_idx = int(e.particles[i].mother2)-1
            e.particles[mother2_idx].daughters = e.particles[mother2_idx].daughters + [i]
        
    for i in range(int(e.eventinfo.nparticles)):
        print(e.particles[i].daughters)
# Out:
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# []
# []
# [2, 3]
# [2, 3]
# ...
